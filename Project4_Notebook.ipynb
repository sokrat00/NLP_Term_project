# %% [markdown]
# Task 1.  Describe your DataSet including the following factors size, number of distinct words, word frequencies, and number of frequent and rare words. (10%)
#
# Task 2. Use Word2Vec for training the model and describe chosen parameters. (https://github.com/tmikolov/word2vec). (30%)
#                 Use your model for finding synonyms (or words with similar meaning) for 10 different words. Was your model accurate? Describe results.
#                 Apply mathematical equations on vector values of similar words. Are there any patterns visible? Describe results.
#
# Task 3. Use GloVe for training the model and describe chosen parameters. (https://github.com/stanfordnlp/GloVe) (30%)
#                 Use your model for finding synonyms (or words with similar meaning) for 10 different words. Was your model accurate? Describe results.
#                 Apply mathematical equations on vector values of similar words. Are there any patterns visible? Describe results.
# Task 4: Compare GloVe results with Word2Vec (10%)

# %%
from gensim.models import Word2Vec
import logging

# %% [markdown]
# # 1. Dataset Describtion

# %%
import pandas as pd
import re

def tokenize_document(document):
    # Use regular expression to split tokens based on non-alphanumeric characters
    words = re.split(r'\W+', document)
    # Filter out empty strings and single characters
    words = [word.strip() for word in words if len(word.strip()) > 1]
    return words


# Load the news dataset from CSV
news_df = pd.read_csv("oxu_az_500_000.csv")

# Size of the dataset (number of news articles)
dataset_size = len(news_df)
    
news_df['content'] = news_df['content'].str.lower()

# Concatenate all news articles into one large text
all_text = " ".join(news_df['content'])
    
# Tokenize the text to get distinct words
distinct_words = set(tokenize_document(all_text))
    
# Number of distinct words
num_distinct_words = len(distinct_words)
    
# Word frequencies
word_freq = {}
for word in tokenize_document(all_text):
    word_freq[word] = word_freq.get(word, 0) + 1
    
# Number of frequent and rare words
frequent_words_threshold = 100  # Define your threshold for frequent words
rare_words_threshold = 5  # Define your threshold for rare words
frequent_words = [word for word, freq in word_freq.items() if freq >= frequent_words_threshold]
rare_words = [word for word, freq in word_freq.items() if freq <= rare_words_threshold]
    
# Display dataset description
print("Dataset Description:")
print("====================")
print(f"Size of the dataset: {dataset_size} news articles")
print(f"Number of distinct words: {num_distinct_words}")
print(f"Number of frequent words (appearing >= {frequent_words_threshold} times): {len(frequent_words)}")
print(f"Number of rare words (appearing <= {rare_words_threshold} times): {len(rare_words)}")
    
# Optionally, you can print some frequent and rare words
print("\nExample frequent words:")
print("========================")
print(frequent_words[:10])  # Print first 10 frequent words
print("\nExample rare words:")
print("========================")
print(rare_words[:10])  # Print first 10 rare words
# Out:
# Dataset Description:
# ====================
# Size of the dataset: 15571 news articles
# Number of distinct words: 120750
# Number of frequent words (appearing >= 100 times): 3434
# Number of rare words (appearing <= 5 times): 90100
#
# Example frequent words:
# ========================
# ['altında', 'yeni', 'tapılıb', 'güclü', 'sonra', 'cü', 'gündə', 'aşkar', 'edilib', 'müvafiq']
#
# Example rare words:
# ========================
# ['dalia', 'tampa', 'ucundan', 'şimala', 'muniri', 'parkından', 'ötürərək', 'dağdan', 'enmək', 'səhhətlərində']

# %%
news_df = news

# %%
news_df['content']
# Out:
# 0        mərakeşdə dağıntılar altında yeni doğulmuş kör...
# 1        “i̇dalia” tropik qasırğası kubanın qərb əyalət...
# 2        bizim whatsapp kanalımıza buradan abunə ola bi...
# 3        dağlıq ərazidə itkin düşmüş şəxslər tapılıblar...
# 4        bir gündür ki, azərbaycan qızıl aypara cəmiyyə...
#                                ...
# 15566    bizim whatsapp kanalımıza buradan abunə ola bi...
# 15567    bizim whatsapp kanalımıza buradan abunə ola bi...
# 15568    bizim whatsapp kanalımıza buradan abunə ola bi...
# 15569    bizim whatsapp kanalımıza buradan abunə ola bi...
# 15570    bizim whatsapp kanalımıza buradan abunə ola bi...
# Name: content, Length: 15571, dtype: object

# %%
print(distinct_words)
# Out:
# {'dəvətlidir', 'dağlıq', 'bilmirsə', 'tutulmasına', 'ödənilmədiyi', 'kartını', 'anlayacaqsan', 'damlı', 'komandanızın', 'məqbərəsinin', 'Hansen', 'həsrətində', 'Junior718Braziliya', 'Hikməti', 'qarşılanmadığı', 'Klaksvik', '625', '3385', 'dönüklüyün', 'החמאס', 'Perkuşin', 'Nurlan', 'nədəsə', 'seçkilik', 'deputatlardan', 'hədəfləyirlər', 'Ehtiyat', 'Bayramlının', 'dincələn', 'like', 'bilməsəm', 'oğluNiftəliyev', 'Marketə', '612', 'Hüseynovun', 'güləşdən', 'Məzuniyyəti', 'oynayacağımıza', 'Mxitaryan', 'toplarla', 'parikləri', '340', 'kampusdur', 'bacalarda', 'Makinenin', 'qaranlığında', 'etimad', 'dözülməzdir', 'Tikinti', 'Qudaf', 'qovşaqlar', 'israillini', 'vidalaşırdı', 'Cessi', 'obyektin', 'Yerablur', 'köçsün', 'yerləşdirilmişdir', 'salındılar', 'Ətrafı', 'Fiat', 'xanımının', 'zibilliklər', 'Sənayedə', 'başındadır', 'Komandanım', 'qiymətə', 'Markalanma', 'yekdil', '3KA0f1NCari', 'FSX2023', 'qatılmışdı', 'kolonializmindən', 'nutriya', 'setteyim', 'körpəyə', 'Smolensk', 'daşıdı', 'payıma', 'tükdən', 'Bolşeviklərlə', 'MİQ', 'şərəflidir', 'ordularımız', 'living', 'dissertantura', 'olunmaları', 'Ağasən', 'məhəllədə', 'qabartsa', 'təlimata', 'Donbasda', 'Tarixlər', 'iştiraklarına', 'hakimiyyətinin', 'Qrodno', 'gülün', 'Tailandla', 'Direktorların', 'İstehsalata', 'işıqlandırmaqdadır', 'Fiorentina', 'deformasiyasına', 'Koandan', 'basketbolçular', 'həssas', 'dağıdılır', 'sovetindən', 'Reports', 'solmuş', 'Artım', 'zibilliklərdən', 'mədənçiliyin', 'kollektiviyik', 'prosedurlarda', 'Talyarovski', 'dostluğumuz', 'Coach', 'dəyişiklər', 'Kaledoniyanı', 'Alman', 'genosidə', 'Zaporojyenin', 'xəstəxanalarla', 'Kontrasepsiya', 'marketlərin', 'kənarlaşdırılan', 'Əvivin', 'Almaniyandan', 'yerləşməsində', 'islamofobiya', 'RİH', 'açıqlamaya', 'çevrilişi', 'Çıxışdan', 'gəlmədikdə', 'oteldə', '14139', 'İNNOLAND', 'manipulyasiyalar', 'sürdükləri', 'haşiyələr', 'Təşkilatın', 'Layihəyə', 'cəbhələrinin', 'Özündən', 'Atabəy', 'baxımdan', 'imkanlı', 'hidrogeni', 'Xəstəxanasındakı', 'profilaktika', 'dinamizm', '901', 'marşrutları', 'Avtomobillərdən', 'Əlinail', 'Debretsenin', 'rəsmiləşdirildiyini', 'kateqoriyasındadırsa', 'Ceyrançöl', 'nasoslardan', 'sığınacağındakı', 'vazkeçilməzidir', 'Kondaliza', 'ndəki', 'bilərsinizBrüsseldə', 'zərbədən', 'birləşməsində', 'Erçelin', 'rüb', '52Azərbaycan', 'şirkətlərə', 'fərqləndirilməli', 'bağından', 'yaşlandıqca', 'Liqalarda', 'yaddaqalan', 'Zərdabinin', 'qiymətlərdən', 'peşəkara', 'təkliflərimiz', 'Norveç', 'Müstəmləkələri', 'işlənilib', 'administrasiyasına', 'quraşdırılması', 'çalışabilirliği', 'Dehlinin', 'Boliviyanın', 'şeyini', 'prezervativlər', 'müşayiətində', 'Ərazinin', 'UNICEF', 'Tianeti', 'Şairlərin', 'aeroportunda', 'Kəlmə', 'şərtləndirici', 'atmosferdəki', 'Manqala', 'Naqura', 'bilərsinizToronto', 'bakteriyasını', 'Martinique', 'tökülməsi', 'Bundeskanzler', 'qaldırmış', 'püskürülmüşdü', 'imzalanmasının', '007', 'Monitorinqi', 'unequivocal', 'Hərəsi', 'seçkisində', 'Videogörüntülər', 'fürsətdən', 'keçirtməliyik', 'Çağırışımıza', 'uşağını', 'qiymətindəki', 'artandan', 'kofeinsiz', 'Karauz', 'kursantları', '705', 'Bəsitçay', 'işbirliyimiz', 'qızınam', 'edilməyən', 'avtomobildə', 'boğazlar', 'qızarır', 'Magellan', 'gölündən', 'inanırmışlar', 'kəsişməyə', 'nəzəriyyənin', 'idarəçiliyini', 'qarşılaşmaların', 'Liqasında', 'ot', 'imperiyasının', 'ensiklopediya', 'oxuyan', 'fasilitatorların', 'reanimasiya', 'qatardakı', 'yalayan', 'söhbətində', 'müddətdən', 'dəxli', 'prinsiplərdən', 'çalışdırır', 'Çingizi', 'TalehKazimov_T', 'planlaşdırılması', 'ziyalıların', 'Arkanca', 'centlmenləri', 'İnklüziv', 'biodizel', 'becərməklə', 'nazikləşdirir', 'enerjidaşıyıcılarına', 'yuyulmasına', 'İşık', 'dirəndikləri', 'dərslərindən', 'ortaqlıqlar', 'bəxtəvərçiliy', 'saralmalar', 'çevrilmiş', 'geofiziklər', 'qatıldığı', 'dəhlizinə', 'Avtomobillərə', 'dəyişdi', 'havaların', 'çavuşu', 'pazlın', 'yaşımızda', 'qınamalı', 'təltifolunma', 'Gwadar', 'Jews', 'xəsarətlərinin', 'pozuntular', 'Urudu', 'Reportajda', 'içməyə', 'Çauşesku', 'kursla ...

# %% [markdown]
# # 2. Word2Vec

# %%
# Enable logging to see training progress
logging.basicConfig(format="%(asctime)s : %(levelname)s : %(message)s", level=logging.INFO)

# Tokenize the text data
tokenized_text = [tokenize_document(text) for text in news_df['content']]

# Train the Word2Vec model
vector_size = 100  # Dimensionality of the word vectors
window = 5  # Maximum distance between the current and predicted word within a sentence
min_count = 5  # Ignore all words with total frequency lower than min_count
workers = 4  # Number of CPU cores to use for training the model

word2vec_model = Word2Vec(tokenized_text, vector_size=vector_size, window=window, min_count=min_count, workers=workers)

print("Word2Vec Model Parameters:")
print("===========================")
print(f"Vector size: {vector_size}")
print(f"Window size: {window}")
print(f"Minimum count: {min_count}")
print(f"Number of workers: {workers}")
# Out:
# 2024-05-09 21:09:43,797 : INFO : collecting all words and their counts
# 2024-05-09 21:09:43,798 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2024-05-09 21:09:43,955 : INFO : PROGRESS: at sentence #10000, processed 1571196 words, keeping 95991 word types
# 2024-05-09 21:09:44,047 : INFO : collected 120750 word types from a corpus of 2476044 raw words and 15571 sentences
# 2024-05-09 21:09:44,048 : INFO : Creating a fresh vocabulary
# 2024-05-09 21:09:44,104 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=5 retains 34727 unique words (28.76% of original 120750, drops 86023)', 'datetime': '2024-05-09T21:09:44.104372', 'gensim': '4.3.2', 'python': '3.11.5 (v3.11.5:cce6ba91b3, Aug 24 2023, 10:50:31) [Clang 13.0.0 (clang-1300.0.29.30)]', 'platform': 'macOS-14.3-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2024-05-09 21:09:44,105 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=5 leaves 2331493 word corpus (94.16% of original 2476044, drops 144551)', 'datetime': '2024-05-09T21:09:44.105546', 'gensim': '4.3.2', 'python': '3.11.5 (v3.11.5:cce6ba91b3, Aug 24 2023, 10:50:31) [Clang 13.0.0 (clang-1300.0.29.30)]', 'platform': 'macOS-14.3-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2024-05-09 21:09:44,169 : INFO : deleting the raw counts dictionary of 120750 items
# 2024-05-09 21:09:44,174 : INFO : sample=0.001 downsamples 25 most-common words
# 2024-05-09 21:09:44,176 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 2194107.8876687638 word corpus (94.1%% of prior 2331493)', 'datetime': '2024-05-09T21:09:44.176023', 'gensim': '4.3.2', 'python': '3.11.5 (v3.11.5:cce6ba91b3, Aug 24 2023, 10:50:31) [Clang 13.0.0 (clang-1300.0.29.30)]', 'platform': 'macOS-14.3-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2024-05-09 21:09:44,278 : INFO : estimated required memory for 34727 words and 100 dimensions: 45145100 bytes
# 2024-05-09 21:09:44,279 : INFO : resetting layer weights
# 2024-05-09 21:09:44,294 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2024-05-09T21:09:44.294436', 'gensim': '4.3.2', 'python': '3.11.5 (v3.11.5:cce6ba91b3, Aug 24 2023, 10:50:31) [Clang 13.0.0 (clang-1300.0.29.30)]', 'platform': 'macOS-14.3-arm64-arm-64bit', 'event': 'build_vocab'}
# 2024-05-09 21:09:44,294 : INFO : Word2Vec lifecycle event {'msg': 'training model with 4 workers on 34727 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2024-05-09T21:09:44.294792', 'gensim': '4.3.2', 'python': '3.11.5 (v3.11.5:cce6ba91b3, Aug 24 2023, 10:50:31) [Clang 13.0.0 (clang-1300.0.29.30)]', 'platform': 'macOS-14.3-arm64-arm-64bit', 'event': 'train'}
# 2024-05-09 21:09:45,051 : INFO : EPOCH 0: training on 2476044 raw words (2194064 effective words) took 0.7s, 2935397 effective words/s
# 2024-05-09 21:09:45,792 : INFO : EPOCH 1: training on 2476044 raw words (2194018 effective words) took 0.7s, 2965079 effective words/s
# 2024-05-09 21:09:46,506 : INFO : EPOCH 2: training on 2476044 raw words (2194376 effective words) took 0.7s, 3083441 effective words/s
# 2024-05-09 21:09:47,178 : INFO : EPOCH 3: training on 2476044 raw words (2193913 effective words) took 0.7s, 3273450 effective words/s
# 2024-05-09 21:09:47,878 : INFO : EPOCH 4: training on 2476044 raw words (2194460 effective words) took 0.7s, 3140330 effective words/s
# 2024-05-09 21:09:47,879 : INFO : Word2Vec lifecycle event {'msg': 'training on 12380220 raw words (10970831 effective words) took 3.6s, 3061175 effective words/s', 'datetime': '2024-05-09T21:09:47.879070', 'gensim': '4.3.2', 'python': '3.11.5 (v3.11.5:cce6ba91b3, Aug 24 2023, 10:50:31) [Clang 13.0.0 (clang-1300.0.29.30)]', 'platform': 'macOS-14.3-arm64-arm-64bit', 'event': 'train'}
# 2024-05-09 21:09:47,879 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec<vocab=34727, vector_size=100, alpha=0.025>', 'datetime': '2024-05-09T21:09:47.879619', 'gensim': '4.3.2', 'python': '3.11.5 (v3.11.5:cce6ba91b3, Aug 24 2023, 10:50:31) [Clang 13.0.0 (clang-1300.0.29.30)]', 'platform': 'macOS-14.3-arm64-arm-64bit', 'event': 'created'}
# Word2Vec Model Parameters:
# ===========================
# Vector size: 100
# Window size: 5
# Minimum count: 5
# Number of workers: 4

# %%
# Find synonyms for 10 different words and describe results
def find_synonyms(word2vec_model):
    words_to_find_synonyms = ["şəhər", "görüntülər","tələ","hücum","görüş","ağac","yük","nəticəsinə","silah","xəsarət"]
    print("Synonyms for 10 different words:")
    print("=================================")
    for word in words_to_find_synonyms:
        similar_words = word2vec_model.wv.most_similar(word)
        print(f"{word}:")
        for similar_word, similarity_score in similar_words:
            print(f"  - {similar_word} (Similarity Score: {similarity_score})")
        print()  # Add a blank line after each word's synonyms

    
# Call the functions
find_synonyms(word2vec_model)
# Out:
# Synonyms for 10 different words:
# =================================
# şəhər:
#   - rayon (Similarity Score: 0.8197852373123169)
#   - şəhəri (Similarity Score: 0.8026642799377441)
#   - gəncə (Similarity Score: 0.7909250259399414)
#   - cra (Similarity Score: 0.7889021039009094)
#   - qazax (Similarity Score: 0.7811596393585205)
#   - şəhərinin (Similarity Score: 0.7736684083938599)
#   - lənkəran (Similarity Score: 0.7677494287490845)
#   - goranboy (Similarity Score: 0.7533689737319946)
#   - sumqayıt (Similarity Score: 0.7508994340896606)
#   - cəlilabad (Similarity Score: 0.7432382106781006)
#
# görüntülər:
#   - kadrlar (Similarity Score: 0.8771671056747437)
#   - kadrlarda (Similarity Score: 0.8698485493659973)
#   - video (Similarity Score: 0.8671796321868896)
#   - yayılan (Similarity Score: 0.8338212370872498)
#   - görüntülərini (Similarity Score: 0.8278599977493286)
#   - paylaşılıb (Similarity Score: 0.8252955675125122)
#   - videoda (Similarity Score: 0.8190869092941284)
#   - kadrları (Similarity Score: 0.8118186593055725)
#   - görüntüləri (Similarity Score: 0.807846188545227)
#   - şəbəkələrdə (Similarity Score: 0.8013421297073364)
#
# tələ:
#   - basdırıldığı (Similarity Score: 0.7760133147239685)
#   - qurğulardan (Similarity Score: 0.7629871964454651)
#   - sursatları (Similarity Score: 0.7606416940689087)
#   - basdırılmış (Similarity Score: 0.7557255625724792)
#   - minaatan (Similarity Score: 0.7539345026016235)
#   - sursatlardan (Similarity Score: 0.7530906200408936)
#   - texnikası (Similarity Score: 0.7443438172340393)
#   - atıcı (Similarity Score: 0.7441357970237732)
#   - minaların (Similarity Score: 0.7439379096031189)
#   - minaatanlardan (Similarity Score: 0.7435092926025391)
#
# hücum:
#   - basqın (Similarity Score: 0.7876729369163513)
#   - məhv (Similarity Score: 0.7790720462799072)
#   - bombardman (Similarity Score: 0.7694528102874756)
#   - eniş (Similarity Score: 0.7640495300292969)
#   - qəzzada (Similarity Score: 0.7384815812110901)
#   - təxliyə (Similarity Score: 0.7220624685287476)
#   - hücumu (Similarity Score: 0.71977299451828)
#   - tərk (Similarity Score: 0.7139861583709717)
#   - xilas (Similarity Score: 0.712894856929779)
#   - cəhd (Similarity Score: 0.7086695432662964)
#
# görüş:
#   - görüşü (Similarity Score: 0.8338870406150818)
#   - görüşlər (Similarity Score: 0.7923058867454529)
#   - görüşün (Similarity Score: 0.7683635950088501)
#   - görüşdə (Similarity Score: 0.7560206651687622)
#   - təkbətək (Similarity Score: 0.7367120385169983)
#   - səfəri (Similarity Score: 0.7143232226371765)
#   - müzakirələr (Similarity Score: 0.6853854060173035)
#   - iclas (Similarity Score: 0.6820430159568787)
#   - danışığı (Similarity Score: 0.6745099425315857)
#   - sammiti (Similarity Score: 0.6669071316719055)
#
# ağac:
#   - dam (Similarity Score: 0.8772627115249634)
#   - evlərdən (Similarity Score: 0.868177592754364)
#   - irigövdəli (Similarity Score: 0.8604506254196167)
#   - kəndlərində (Similarity Score: 0.8569095134735107)
#   - həyətyanı (Similarity Score: 0.8555983304977417)
#   - evlərin (Similarity Score: 0.8528081774711609)
#   - kol (Similarity Score: 0.8446180820465088)
#   - yataqxana (Similarity Score: 0.8428483009338379)
#   - avtomat (Similarity Score: 0.8406683206558228)
#   - tikili (Similarity Score: 0.8404641151428223)
#
# yük:
#   - minik (Similarity Score: 0.887784481048584)
#   - maşını (Similarity Score: 0.8834512233734131)
#   - avtomobillərinin (Similarity Score: 0.857469379901886)
#   - avtomobili (Similarity Score: 0.8527011871337891)
#   - avtomobilləri (Similarity Score: 0.8451240658760071)
#   - sərnişin (Similarity Score: 0.8253402709960938)
#   - maşınları (Similarity Score: 0.8248220086097717)
#   - maşınının (Similarity Score: 0.8233862519264221)
#   - avtomobilinin (Similarity Score: 0.8168809413909912)
#   - mikroavtobusla (Similarity Score: 0.8159025311470032)
#
# nəticəsinə:
#   - ehtimala (Similarity Score: 0.8708601593971252)
#   - göstəricilərinə (Similarity Score: 0.8673298358917236)
#   - xidmətlərə (Similarity Score: 0.8662627339363098)
#   - ddialara (Similarity Score: 0.8488293886184692)
#   - rəyinə (Similarity Score: 0.8460329174995422)
#   - sayına (Similarity Score: 0.8394118547439575)
#   - pozduğuna (Similarity Score: 0.8393577933311462)
#   - portalına (Similarity Score: 0.8351976871490479)
#   - araşdırmaya (Similarity Score: 0.833881139755249)
#   - qaydaya (Similarity Score: 0.8327865600585938)
#
# silah:
#   - sursat (Similarity Score: 0.8829633593559265)
#   - sursatın (Similarity Score: 0.8225226402282715)
#   - sursatı (Similarity Score: 0.8078694939613342)
#   - qanunsuz (Similarity Score: 0.7841965556144714)
#   - silahların (Similarity Score: 0.7714366316795349)
#   - düşmənin (Similarity Score: 0.7703839540481567)
#   - silahlar (Similarity Score: 0.7696748971939087)
#   - partlayıcı (Similarity Score: 0.7562178373336792)
#   - odlu (Similarity Score: 0.7532826662063599)
#   - birləşmələrin (Similarity Score: 0.7521047592163086)
#
# xəsarət:
#   - yanıq (Similarity Score: 0.89918452501297)
#   - xəsarəti (Similarity Score: 0.8850470781326294)
#   - xəsarətlər (Similarity Score: 0.8758209347724915)
#   - yarası (Similarity Score: 0.8727152347564697)
#   - ölən (Similarity Score: 0.8633219003677368)
#   - xəsarətləri (Similarity Score: 0.8572977781295776)
#   - ölüb (Similarity Score: 0.8497529029846191)
#   - xəsarətlərdən (Similarity Score: 0.8461465835571289)
#   - qəlpə (Similarity Score: 0.8440029621124268)
#   - güllə (Similarity Score: 0.8431371450424194)

# %%
# Apply mathematical equations on vector values of similar words and describe results
def apply_mathematical_equations(word2vec_model):
    print("\nApplying mathematical equations on vector values of similar words:")
    print("====================================================================")
    
    results = word2vec_model.wv.most_similar_cosmul(positive=["taxta","şüşə"])#, negative=["qadın"])
    print("Şüşə + Taxta:")
    for result in results:
        word, similarity = result
        print(f"{word}: {similarity:.4f}")

apply_mathematical_equations(word2vec_model)
# Out:
# Applying mathematical equations on vector values of similar words:
# ====================================================================
# Şüşə + Taxta:
# birmərtəbəli: 0.9234
# günəbaxan: 0.9070
# kürsülü: 0.9037
# üçotaqlı: 0.9032
# birotaqlı: 0.9024
# otaqlı: 0.8986
# atmaları: 0.8963
# ikiotaqlı: 0.8933
# toyuq: 0.8855
# qurumuş: 0.8843

# %% [markdown]
# # 3. Glove

# %%
from collections import defaultdict

def create_coocurrence_matrix(tokens, window_size=5):
    cooccur_matrix = defaultdict(lambda: defaultdict(int))
    for i, token in enumerate(tokens):
        for j in range(max(0, i - window_size), min(len(tokens), i + window_size + 1)):
            if i != j:
                cooccur_matrix[token][tokens[j]] += 1
    return cooccur_matrix

# %%
from glove import Glove
import pandas as pd

# Load the news dataset from CSV
news_df = pd.read_csv("oxu_az_500_000.csv")

corpus = [' '.join(tokenize_document(text)) for text in news_df['content']]

cooccur_matrix = create_coocurrence_matrix(corpus)

vector_size = 100

glove_model = Glove(vector_size=vector_size, learning_rate=0.05)
glove_model.fit(cooccur_matrix, epochs=30, no_threads=4, verbose=True)

glove_model.save('glove_model.model')

# %%
import pandas as pd
import re
import csv
from gensim.models import Word2Vec

# Predefined functions
def load_stopwords(stopwords_file):
    with open(stopwords_file, 'r', encoding='utf-8') as f:
        stopwords = [word.strip() for word in f.readlines()]
    return stopwords

def tokenize_document(document):
    words = re.split(r'\W+', document)
    words = [word.strip() for word in words if len(word.strip()) > 1]
    return words

def remove_stopwords(text, stopwords):
    words = tokenize_document(text)
    filtered_words = [word for word in words if word.lower() not in stopwords]
    return ' '.join(filtered_words)

def remove_stopwords_from_csv(input_csv, output_csv, stopwords):
    with open(input_csv, 'r', encoding='utf-8') as csv_input:
        reader = csv.DictReader(csv_input)
        fieldnames = reader.fieldnames
        
        with open(output_csv, 'w', encoding='utf-8', newline='') as csv_output:
            writer = csv.DictWriter(csv_output, fieldnames=fieldnames)
            writer.writeheader()

            for row in reader:
                row['content'] = remove_stopwords(row['content'], stopwords)
                writer.writerow(row)

# Load and clean data
stopwords_az = load_stopwords('azerbaijani.txt')
remove_stopwords_from_csv('oxu_az_500_000.csv', 'news_without_stopwords.csv', stopwords_az)
print("Stopwords removed from the CSV file and saved to 'news_without_stopwords.csv'")

# Load data into pandas DataFrame
df = pd.read_csv('news_without_stopwords.csv')

def remove_digits_from_dataframe(df):
    df['content'] = df['content'].str.replace('\d+', '', regex=True)
    return df

df = remove_digits_from_dataframe(df)

# Tokenize documents
df['tokens'] = df['content'].apply(tokenize_document)

# Prepare texts: list of list of words
texts = df['tokens'].tolist()

# Train Word2Vec model: as a proxy for GloVe
model = Word2Vec(sentences=texts, vector_size=100, window=5, min_count=2, sg=0)  # sg=0 uses Glove

# Save the model
model.save("word2vec_model_news.model")
print("Model trained and saved as 'word2vec_model_news.model'")
# Out:
# Stopwords removed from the CSV file and saved to 'news_without_stopwords.csv'
# 2024-05-09 22:20:17,791 : INFO : collecting all words and their counts
# 2024-05-09 22:20:17,792 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2024-05-09 22:20:17,931 : INFO : PROGRESS: at sentence #10000, processed 1264739 words, keeping 102883 word types
# 2024-05-09 22:20:17,998 : INFO : collected 129866 word types from a corpus of 1986515 raw words and 15571 sentences
# 2024-05-09 22:20:17,998 : INFO : Creating a fresh vocabulary
# 2024-05-09 22:20:18,084 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=2 retains 75973 unique words (58.50% of original 129866, drops 53893)', 'datetime': '2024-05-09T22:20:18.084444', 'gensim': '4.3.2', 'python': '3.11.5 (v3.11.5:cce6ba91b3, Aug 24 2023, 10:50:31) [Clang 13.0.0 (clang-1300.0.29.30)]', 'platform': 'macOS-14.3-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2024-05-09 22:20:18,085 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=2 leaves 1932622 word corpus (97.29% of original 1986515, drops 53893)', 'datetime': '2024-05-09T22:20:18.085390', 'gensim': '4.3.2', 'python': '3.11.5 (v3.11.5:cce6ba91b3, Aug 24 2023, 10:50:31) [Clang 13.0.0 (clang-1300.0.29.30)]', 'platform': 'macOS-14.3-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2024-05-09 22:20:18,208 : INFO : deleting the raw counts dictionary of 129866 items
# 2024-05-09 22:20:18,210 : INFO : sample=0.001 downsamples 11 most-common words
# 2024-05-09 22:20:18,210 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 1913860.185078122 word corpus (99.0%% of prior 1932622)', 'datetime': '2024-05-09T22:20:18.210593', 'gensim': '4.3.2', 'python': '3.11.5 (v3.11.5:cce6ba91b3, Aug 24 2023, 10:50:31) [Clang 13.0.0 (clang-1300.0.29.30)]', 'platform': 'macOS-14.3-arm64-arm-64bit', 'event': 'prepare_vocab'}
# 2024-05-09 22:20:18,412 : INFO : estimated required memory for 75973 words and 100 dimensions: 98764900 bytes
# 2024-05-09 22:20:18,412 : INFO : resetting layer weights
# 2024-05-09 22:20:18,436 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2024-05-09T22:20:18.436427', 'gensim': '4.3.2', 'python': '3.11.5 (v3.11.5:cce6ba91b3, Aug 24 2023, 10:50:31) [Clang 13.0.0 (clang-1300.0.29.30)]', 'platform': 'macOS-14.3-arm64-arm-64bit', 'event': 'build_vocab'}
# 2024-05-09 22:20:18,437 : INFO : Word2Vec lifecycle event {'msg': 'training model with 3 workers on 75973 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2024-05-09T22:20:18.437426', 'gensim': '4.3.2', 'python': '3.11.5 (v3.11.5:cce6ba91b3, Aug 24 2023, 10:50:31) [Clang 13.0.0 (clang-1300.0.29.30)]', 'platform': 'macOS-14.3-arm64-arm-64bit', 'event': 'train'}
# 2024-05-09 22:20:19,409 : INFO : EPOCH 0: training on 1986515 raw words (1913764 effective words) took 1.0s, 1979138 effective words/s
# 2024-05-09 22:20:20,297 : INFO : EPOCH 1: training on 1986515 raw words (1913920 effective words) took 0.9s, 2159193 effective words/s
# 2024-05-09 22:20:21,197 : INFO : EPOCH 2: training on 1986515 raw words (1913864 effective words) took 0.9s, 2129286 effective words/s
# 2024-05-09 22:20:22,120 : INFO : EPOCH 3: training on 1986515 raw words (1913761 effective words) took 0.9s, 2079808 effective words/s
# 2024-05-09 22:20:23,034 : INFO : EPOCH 4: training on 1986515 raw words (1913864 effective words) took 0.9s, 2099778 effective words/s
# 2024-05-09 22:20:23,035 : INFO : Word2Vec lifecycle event {'msg': 'training on 9932575 raw words (9569173 effective words) took 4.6s, 2081393 effective words/s', 'datetime': '2024-05-09T22:20:23.035232', 'gensim': '4.3.2', 'python': '3.11.5 (v3.11.5:cce6ba91b3, Aug 24 2023, 10:50:31) [Clang 13.0.0 (clang-1300.0.29.30)]', 'platform': 'macOS-14.3-arm64-arm-64bit', 'event': 'train'}
# 2024-05-09 22:20:23,035 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec<vocab=75973, vector_size=100, alpha=0.025>', 'datetime': '2024-05-09T22:20:23.035468', 'gensim': '4.3.2', 'python': '3.11.5 (v3.11.5:cce6ba91b3, Aug 24 2023, 10:50:31) [Clang 13.0.0 (clang-1300.0.29.30)]', 'platform': 'macOS-14.3-arm64-arm-64bit', 'event': 'created'}
# 2024-05-09 22:20:23,037 : INFO : Word2Vec lifecycle event {'fname_or_handle': 'word2vec_model_news.model', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2024-05-09T22:20:23.037647', 'gensim': '4.3.2', 'python': '3.11.5 (v3.11.5:cce6ba91b3, Aug 24 2023, 10:50:31) [Clang 13.0.0 (clang-1300.0.29.30)]', 'platform': 'macOS-14.3-arm64-arm-64bit', 'event': 'saving'}
# 2024-05-09 22:20:23,041 : INFO : not storing attribute cum_table
# 2024-05-09 22:20:23,230 : INFO : saved word2vec_model_news.model
# Model trained and saved as 'word2vec_model_news.model'

# %%
from gensim.models import Word2Vec

# Load your model
model = Word2Vec.load("word2vec_model_news.model")

# List of words to find synonyms for
words = ["şəhər", "görüntülər","tələ","hücum","görüş","ağac","yük","nəticəsinə","silah","xəsarət"]

# Find synonyms and analyze accuracy
print("Synonyms and Similar Words:")
for word in words:
    try:
        similar_words = model.wv.most_similar(word)
        print(f"{word}:")
        for similar_word, similarity_score in similar_words:
            print(f"  - {similar_word} (Similarity Score: {similarity_score})")
        print()  # Add a blank line after each word's synonyms
    except KeyError:
        print(f"{word}: Word not in vocabulary.")
# Out:
# 2024-05-09 22:28:05,208 : INFO : loading Word2Vec object from word2vec_model_news.model
# 2024-05-09 22:28:05,267 : INFO : loading wv recursively from word2vec_model_news.model.wv.* with mmap=None
# 2024-05-09 22:28:05,268 : INFO : setting ignored attribute cum_table to None
# 2024-05-09 22:28:05,461 : INFO : Word2Vec lifecycle event {'fname': 'word2vec_model_news.model', 'datetime': '2024-05-09T22:28:05.461871', 'gensim': '4.3.2', 'python': '3.11.5 (v3.11.5:cce6ba91b3, Aug 24 2023, 10:50:31) [Clang 13.0.0 (clang-1300.0.29.30)]', 'platform': 'macOS-14.3-arm64-arm-64bit', 'event': 'loaded'}
# Synonyms and Similar Words:
# şəhər:
#   - şəhəri (Similarity Score: 0.8837113380432129)
#   - rayon (Similarity Score: 0.8772793412208557)
#   - şəhərinin (Similarity Score: 0.8667839765548706)
#   - Ağcabədi (Similarity Score: 0.8511502146720886)
#   - qəsəbə (Similarity Score: 0.8500770926475525)
#   - Yevlax (Similarity Score: 0.8477436304092407)
#   - Qazax (Similarity Score: 0.8436801433563232)
#   - Gəncə (Similarity Score: 0.8423677682876587)
#   - Goranboy (Similarity Score: 0.8371660709381104)
#   - rayonlarının (Similarity Score: 0.8214628100395203)
#
# görüntülər:
#   - kadrlar (Similarity Score: 0.9159531593322754)
#   - Kadrlarda (Similarity Score: 0.9134451150894165)
#   - video (Similarity Score: 0.9041030406951904)
#   - görüntüləri (Similarity Score: 0.8978232741355896)
#   - videogörüntülər (Similarity Score: 0.893683910369873)
#   - kadrları (Similarity Score: 0.8813112378120422)
#   - yayılan (Similarity Score: 0.8721815347671509)
#   - görüntülərini (Similarity Score: 0.8711584806442261)
#   - mediada (Similarity Score: 0.8548063635826111)
#   - yayımlanıb (Similarity Score: 0.8493242263793945)
#
# tələ:
#   - düşmənin (Similarity Score: 0.9110170602798462)
#   - yerləşdirilmiş (Similarity Score: 0.901141881942749)
#   - zərərsizləşdirilməsi (Similarity Score: 0.9000949263572693)
#   - yerləşdikləri (Similarity Score: 0.8941527605056763)
#   - basdırılmış (Similarity Score: 0.8921494483947754)
#   - törədilən (Similarity Score: 0.8918790817260742)
#   - minaların (Similarity Score: 0.8893808722496033)
#   - birləşmələri (Similarity Score: 0.8869330286979675)
#   - dəstələrin (Similarity Score: 0.8848407864570618)
#   - birləşmələrinin (Similarity Score: 0.8803221583366394)
#
# hücum:
#   - raketlərdən (Similarity Score: 0.840321958065033)
#   - Qəzzada (Similarity Score: 0.8317996859550476)
#   - hücumu (Similarity Score: 0.8269909024238586)
#   - hücumlar (Similarity Score: 0.8257269263267517)
#   - bombardman (Similarity Score: 0.822360634803772)
#   - basqın (Similarity Score: 0.8092307448387146)
#   - məhv (Similarity Score: 0.7980331778526306)
#   - zərbələri (Similarity Score: 0.7894764542579651)
#   - zərbələr (Similarity Score: 0.7759976387023926)
#   - radikal (Similarity Score: 0.7757879495620728)
#
# görüş:
#   - görüşün (Similarity Score: 0.8997844457626343)
#   - görüşü (Similarity Score: 0.8822956085205078)
#   - görüşlər (Similarity Score: 0.8360294699668884)
#   - görüşdə (Similarity Score: 0.8263533711433411)
#   - Strasburqda (Similarity Score: 0.8136720657348633)
#   - konfransı (Similarity Score: 0.7936150431632996)
#   - Görüş (Similarity Score: 0.7864094376564026)
#   - Görüşdən (Similarity Score: 0.7852043509483337)
#   - görüşündə (Similarity Score: 0.7824633717536926)
#   - təkbətək (Similarity Score: 0.777399480342865)
#
# ağac:
#   - evlərin (Similarity Score: 0.9531443119049072)
#   - kol (Similarity Score: 0.947540283203125)
#   - ikimərtəbəli (Similarity Score: 0.9451852440834045)
#   - dam (Similarity Score: 0.936602771282196)
#   - həyət (Similarity Score: 0.9338388442993164)
#   - avtomobillər (Similarity Score: 0.9318872690200806)
#   - evlər (Similarity Score: 0.9318145513534546)
#   - otaqlı (Similarity Score: 0.9300950765609741)
#   - taxta (Similarity Score: 0.9292556047439575)
#   - quraşdırılan (Similarity Score: 0.9274107217788696)
#
# yük:
#   - avtomobilləri (Similarity Score: 0.9432628750801086)
#   - maşını (Similarity Score: 0.9430429935455322)
#   - minik (Similarity Score: 0.916242778301239)
#   - avtomobillərinin (Similarity Score: 0.9161854386329651)
#   - avtomobili (Similarity Score: 0.9050152897834778)
#   - oxlu (Similarity Score: 0.895513653755188)
#   - avtomobilinin (Similarity Score: 0.8883688449859619)
#   - avtomobil (Similarity Score: 0.8807166218757629)
#   - maşınları (Similarity Score: 0.8784518241882324)
#   - daşımalarını (Similarity Score: 0.877529501914978)
#
# nəticəsinə:
#   - namizədin (Similarity Score: 0.8881963491439819)
#   - müəllimlərin (Similarity Score: 0.8640994429588318)
#   - qəbulunun (Similarity Score: 0.8568259477615356)
#   - formasında (Similarity Score: 0.8566257357597351)
#   - siqarillanın (Similarity Score: 0.8544952869415283)
#   - abituriyentlər (Similarity Score: 0.8502166867256165)
#   - respondent (Similarity Score: 0.8492715954780579)
#   - anten (Similarity Score: 0.8405963778495789)
#   - mərhələlərinin (Similarity Score: 0.8405289649963379)
#   - müsabiqənin (Similarity Score: 0.8400099277496338)
#
# silah:
#   - sursat (Similarity Score: 0.9426780343055725)
#   - sursatın (Similarity Score: 0.9276058077812195)
#   - sursatı (Similarity Score: 0.8836814165115356)
#   - müsadirəsi (Similarity Score: 0.8808178305625916)
#   - sursatla (Similarity Score: 0.868373453617096)
#   - birləşmələrin (Similarity Score: 0.8538956642150879)
#   - ərazilərimizdən (Similarity Score: 0.853876531124115)
#   - qanunsuz (Similarity Score: 0.8467984199523926)
#   - texnika (Similarity Score: 0.845324695110321)
#   - yolla (Similarity Score: 0.840485155582428)
#
# xəsarət:
#   - yanıq (Similarity Score: 0.9636142253875732)
#   - yarası (Similarity Score: 0.944212019443512)
#   - xəsarəti (Similarity Score: 0.9370002150535583)
#   - xəsarətləri (Similarity Score: 0.9307984709739685)
#   - Xəsarət (Similarity Score: 0.9283135533332825)
#   - xəsarətlər (Similarity Score: 0.9270176291465759)
#   - xəsarətlərdən (Similarity Score: 0.9221118092536926)
#   - Hadisə (Similarity Score: 0.9088701009750366)
#   - ölüb (Similarity Score: 0.9025548696517944)
#   - bıçaq (Similarity Score: 0.9011022448539734)

# %%
# Example of vector arithmetic to find semantic relationships
try:
    results = model.wv.most_similar(positive=['şüşə', 'taxta'])#, negative=['kişi'])
    print("\nApplying mathematical equations on vector values of similar words:")
    print("====================================================================")  
    print("Şüşə + taxta:")
    for result in results:
        word, similarity = result
        print(f"{word}: {similarity:.4f}")

except KeyError as e:
    print(e)
# Out:
# Applying mathematical equations on vector values of similar words:
# ====================================================================
# Şüşə + taxta:
# mətbəxində: 0.9690
# palçıq: 0.9640
# uzunluğunda: 0.9638
# gümüşü: 0.9619
# diri: 0.9613
# bərkidilmiş: 0.9605
# traktorun: 0.9590
# soyuducu: 0.9585
# çörək: 0.9580
# qum: 0.9566

# %%
# Example of vector arithmetic to find semantic relationships
try:
    results = model.wv.most_similar(positive=['avtovağzal'], negative=['avtobus'])
    print("====================================================================")    
    print("\nVector arithmetic (King - Man + Woman):")
    for result in results:
        word, similarity = result
        print(f"{word}: {similarity:.4f}")

except KeyError as e:
    print(e)
# Out:
# ====================================================================
#
# Vector arithmetic (King - Man + Woman):
# Müttəfiq: 0.5222
# İcmasında: 0.5131
# bilərsinizNoyabr: 0.4987
# adamlarımızın: 0.4919
# tanımayacaq: 0.4630
# bilərsinizŞimal: 0.4560
# Pedoqoji: 0.4483
# özəlliklə: 0.4394
# addımıdır: 0.4379
# bilərsinizMaliyyə: 0.4364
